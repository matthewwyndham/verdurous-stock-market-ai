# %%
from numpy import *
from pandas import *
from myapikey import APIkey
# for jupyter notebook this is nice
# %matplotlib inline
# I use a dark theme so I set it to white.
import matplotlib.pyplot as plt
COLOR = 'white'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key=APIkey)
# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('GOOGL')

# %%
from alpha_vantage.timeseries import TimeSeries

ts = TimeSeries(key=APIkey, output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
from alpha_vantage.techindicators import TechIndicators

ti = TechIndicators(key=APIkey, output_format='pandas')
data, meta_data = ti.get_bbands(symbol='MSFT', interval='60min', time_period=60)
data.plot()
plt.title('BBbands indicator for  MSFT stock (60 min)')
plt.show()

# %%
from alpha_vantage.sectorperformance import SectorPerformances

sp = SectorPerformances(key='YOUR_API_KEY', output_format='pandas')
data, meta_data = sp.get_sector()
data['Rank A: Real-Time Performance'].plot(kind='bar')
plt.title('Real Time Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %%
# Implement stuff from here: https://www.alphavantage.co/documentation/
# Get as many datapoints as possible, but consistently. May require multiple API calls?
# All of today, all of yesterday, all of two days ago, general from last week,
# general from last month, super general from all year?

# %%
from alpha_vantage.timeseries import TimeSeries

ts = TimeSeries(key=APIkey, output_format='pandas', indexing_type='integer')
data, meta_data = ts.get_intraday(symbol='MSFT', interval='1min', outputsize='full')
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-28c0eeff52b4> in <module>
#       1 from alpha_vantage.timeseries import TimeSeries
#       2
# ----> 3 ts = TimeSeries(key=APIkey, output_format='pandas', indexing_type='integer')
#       4 data, meta_data = ts.get_intraday(symbol='MSFT', interval='1min', outputsize='full')
#       5 print(data)
#
# NameError: name 'APIkey' is not defined

# %%
# https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html

# print(data.to_numpy())
# for t in data.to_numpy():
#     for h in t:
#         print(h, end=' ')

# %%
import datetime
now = datetime.datetime.now()
now.strftime("%Y-%m-%d")
# Out:
# '2019-02-20'

# %%
20190220 - 20190220
# Out:
# 0

# %%
print(data.describe())
# Out:
#            1. open      2. high       3. low     4. close     5. volume
# count  1950.000000  1950.000000  1950.000000  1950.000000  1.950000e+03
# mean    111.165037   111.194297   111.137013   111.167496  5.501663e+04
# std       1.406356     1.401987     1.409549     1.404164  6.222524e+04
# min     106.950000   107.010000   106.880000   107.010000  4.084000e+03
# 25%     110.651450   110.682500   110.630000   110.660000  2.673125e+04
# 50%     111.635000   111.660000   111.610000   111.637500  4.032250e+04
# 75%     112.130000   112.150000   112.105550   112.130000  6.279725e+04
# max     113.180000   113.230000   113.165000   113.175000  1.132392e+06

# %%
print(data['1. open'])
# Out:
# date
# 2019-02-21 09:31:00    106.9500
# 2019-02-21 09:32:00    107.0600
# 2019-02-21 09:33:00    107.2100
# 2019-02-21 09:34:00    107.4300
# 2019-02-21 09:35:00    107.4700
# 2019-02-21 09:36:00    107.4000
# 2019-02-21 09:37:00    107.4400
# 2019-02-21 09:38:00    107.5000
# 2019-02-21 09:39:00    107.2700
# 2019-02-21 09:40:00    107.3000
# 2019-02-21 09:41:00    107.3700
# 2019-02-21 09:42:00    107.5050
# 2019-02-21 09:43:00    107.2900
# 2019-02-21 09:44:00    107.2100
# 2019-02-21 09:45:00    107.1600
# 2019-02-21 09:46:00    107.1200
# 2019-02-21 09:47:00    107.0900
# 2019-02-21 09:48:00    107.1500
# 2019-02-21 09:49:00    107.1000
# 2019-02-21 09:50:00    107.0800
# 2019-02-21 09:51:00    107.0600
# 2019-02-21 09:52:00    107.1300
# 2019-02-21 09:53:00    107.0600
# 2019-02-21 09:54:00    107.1300
# 2019-02-21 09:55:00    107.1100
# 2019-02-21 09:56:00    107.1100
# 2019-02-21 09:57:00    107.0751
# 2019-02-21 09:58:00    107.2136
# 2019-02-21 09:59:00    107.2800
# ...

# %%
print(len(data))
# Out:
# 1950

# %%
data = data.dropna(how='any')
print(len(data))
# Out:
# 1950
